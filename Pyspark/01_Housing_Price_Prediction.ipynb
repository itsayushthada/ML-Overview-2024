# %%
# !pip install pyspark
# !pip install findspark

import findspark
findspark.init()
# Out:
# Collecting pyspark
#   Downloading pyspark-3.5.2.tar.gz (317.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.3/317.3 MB 1.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.5.2-py2.py3-none-any.whl size=317812365 sha256=537ad6c91ef41031c67df594493ccdb63a8079efb313c00c31e9aab451ec172b
#   Stored in directory: /root/.cache/pip/wheels/34/34/bd/03944534c44b677cd5859f248090daa9fb27b3c8f8e5f49574
# Successfully built pyspark
# Installing collected packages: pyspark
# Successfully installed pyspark-3.5.2
# Collecting findspark
#   Downloading findspark-2.0.1-py2.py3-none-any.whl.metadata (352 bytes)
# Downloading findspark-2.0.1-py2.py3-none-any.whl (4.4 kB)
# Installing collected packages: findspark
# Successfully installed findspark-2.0.1

# %%
from pyspark.sql import SparkSession
import pandas as pd
import numpy as np

spark = SparkSession.builder\
                    .master("local[*]")\
                    .appName('example_spark')\
                    .getOrCreate()

spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://f3b8cb6f75a8:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.5.2</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>example_spark</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ### Loading Data

# %%
# Reading Data
train_df = spark.read.csv('/content/sample_data/california_housing_train.csv', header=True)
test_df  = spark.read.csv('/content/sample_data/california_housing_test.csv', header=True)

train_df.limit(5).toPandas()
# Out:
#      longitude   latitude housing_median_age  total_rooms total_bedrooms  \
# 0  -114.310000  34.190000          15.000000  5612.000000    1283.000000
# 1  -114.470000  34.400000          19.000000  7650.000000    1901.000000
# 2  -114.560000  33.690000          17.000000   720.000000     174.000000
# 3  -114.570000  33.640000          14.000000  1501.000000     337.000000
# 4  -114.570000  33.570000          20.000000  1454.000000     326.000000
#
#     population  households median_income median_house_value
# 0  1015.000000  472.000000      1.493600       66900.000000
# 1  1129.000000  463.000000      1.820000       80100.000000
# 2   333.000000  117.000000      1.650900       85700.000000
# 3   515.000000  226.000000      3.191700       73400.000000
# 4   624.000000  262.000000      1.925000       65500.000000

# %%
predictors, response = train_df.columns[:-1], train_df.columns[-1]

# %%
train_df.printSchema()
# Out:
# root
#  |-- longitude: string (nullable = true)
#  |-- latitude: string (nullable = true)
#  |-- housing_median_age: string (nullable = true)
#  |-- total_rooms: string (nullable = true)
#  |-- total_bedrooms: string (nullable = true)
#  |-- population: string (nullable = true)
#  |-- households: string (nullable = true)
#  |-- median_income: string (nullable = true)
#  |-- median_house_value: string (nullable = true)

# %%
from pyspark.sql.types import DoubleType

# %%
for col in train_df.columns:
  train_df = train_df.withColumn(col, train_df[col].cast(DoubleType()))
  test_df = test_df.withColumn(col, test_df[col].cast(DoubleType()))

# %%
train_df.printSchema()
# Out:
# root
#  |-- longitude: double (nullable = true)
#  |-- latitude: double (nullable = true)
#  |-- housing_median_age: double (nullable = true)
#  |-- total_rooms: double (nullable = true)
#  |-- total_bedrooms: double (nullable = true)
#  |-- population: double (nullable = true)
#  |-- households: double (nullable = true)
#  |-- median_income: double (nullable = true)
#  |-- median_house_value: double (nullable = true)

# %% [markdown]
# ### Comparing Data Statistics

# %%
train_df.summary().toPandas()
# Out:
#   summary            longitude            latitude  housing_median_age  \
# 0   count                17000               17000               17000
# 1    mean  -119.56210823529375    35.6252247058827   28.58935294117647
# 2  stddev   2.0051664084260357  2.1373397946570867  12.586936981660406
# 3     min          -114.310000           32.540000            1.000000
# 4     25%              -121.79               33.93                18.0
# 5     50%              -118.49               34.25                29.0
# 6     75%               -118.0               37.72                37.0
# 7     max          -124.350000           41.950000            9.000000
#
#          total_rooms     total_bedrooms          population  \
# 0              17000              17000               17000
# 1  2643.664411764706  539.4108235294118  1429.5739411764705
# 2  2179.947071452777  421.4994515798648   1147.852959159527
# 3        1000.000000           1.000000          100.000000
# 4             1462.0              297.0               789.0
# 5             2127.0              434.0              1167.0
# 6             3150.0              648.0              1720.0
# 7        9992.000000         999.000000          999.000000
#
#           households       median_income  median_house_value
# 0              17000               17000               17000
# 1  501.2219411764706   3.883578100000021  207300.91235294117
# 2  384.5208408559016  1.9081565183791036  115983.76438720895
# 3           1.000000            0.499900       100000.000000
# 4              282.0              2.5662            119400.0
# 5              409.0              3.5445            180400.0
# 6              605.0              4.7639            265000.0
# 7         999.000000            9.907100        99900.000000

# %%
test_df.summary().toPandas()
# Out:
#   summary            longitude            latitude  housing_median_age  \
# 0   count                 3000                3000                3000
# 1    mean  -119.58920000000029   35.63538999999999  28.845333333333333
# 2  stddev   1.9949362939550166  2.1296695233438334  12.555395554955757
# 3     min          -114.490000           32.560000            1.000000
# 4     25%              -121.81               33.93                18.0
# 5     50%              -118.49               34.27                29.0
# 6     75%              -118.02               37.69                37.0
# 7     max          -124.180000           41.920000            9.000000
#
#          total_rooms      total_bedrooms          population  \
# 0               3000                3000                3000
# 1  2599.578666666667   529.9506666666666  1402.7986666666666
# 2  2155.593331625582  415.65436813632306  1030.5430124122424
# 3        1000.000000          100.000000          100.000000
# 4             1401.0               291.0               780.0
# 5             2105.0               437.0              1155.0
# 6             3128.0               636.0              1742.0
# 7        9998.000000          999.000000          999.000000
#
#            households       median_income  median_house_value
# 0                3000                3000                3000
# 1             489.912   3.807271799999998          205846.275
# 2  365.42270980552615  1.8545117296914775  113119.68746964622
# 3           10.000000            0.499900       100000.000000
# 4               273.0              2.5437            121200.0
# 5               409.0              3.4871            177600.0
# 6               597.0              4.6556            263900.0
# 7          998.000000            9.870800        99800.000000

# %% [markdown]
# ### Null Counts

# %%
import pyspark.sql.functions as f
get_nulls = lambda df: df.select(*[f.count(f.when(f.isnan(c) | f.col(c).isNull(), c)).alias(c) for c in df.columns]).show()

# %%
get_nulls(train_df)
# Out:
# +---------+--------+------------------+-----------+--------------+----------+----------+-------------+------------------+
# |longitude|latitude|housing_median_age|total_rooms|total_bedrooms|population|households|median_income|median_house_value|
# +---------+--------+------------------+-----------+--------------+----------+----------+-------------+------------------+
# |        0|       0|                 0|          0|             0|         0|         0|            0|                 0|
# +---------+--------+------------------+-----------+--------------+----------+----------+-------------+------------------+

# %%
get_nulls(test_df)
# Out:
# +---------+--------+------------------+-----------+--------------+----------+----------+-------------+------------------+
# |longitude|latitude|housing_median_age|total_rooms|total_bedrooms|population|households|median_income|median_house_value|
# +---------+--------+------------------+-----------+--------------+----------+----------+-------------+------------------+
# |        0|       0|                 0|          0|             0|         0|         0|            0|                 0|
# +---------+--------+------------------+-----------+--------------+----------+----------+-------------+------------------+

# %% [markdown]
# ### Correlation Test

# %%
from pyspark.ml.stat import Correlation
from pyspark.ml.feature import VectorAssembler

# %%
def get_correlation(df, var_names):
  assembler = VectorAssembler(inputCols=var_names, outputCol="features", handleInvalid='keep')
  new_df = assembler.transform(df).select("features")
  correlation = Correlation.corr(new_df, "features", "pearson").collect()[0][0].toArray()
  corr_matrix = pd.DataFrame(correlation, columns=var_names, index=var_names)
  corr_matrix = corr_matrix.reset_index().melt(id_vars="index")
  corr_matrix.columns = ["var_1", "var_2", "correlation"]
  return corr_matrix

# %%
# Correlation among variables in training set.
train_corr = get_correlation(train_df, predictors)
train_corr
# Out:
#                  var_1          var_2  correlation
# 0            longitude      longitude     1.000000
# 1             latitude      longitude    -0.925208
# 2   housing_median_age      longitude    -0.114250
# 3          total_rooms      longitude     0.047010
# 4       total_bedrooms      longitude     0.071802
# ..                 ...            ...          ...
# 59         total_rooms  median_income     0.195383
# 60      total_bedrooms  median_income    -0.013495
# 61          population  median_income    -0.000638
# 62          households  median_income     0.007644
# 63       median_income  median_income     1.000000
#
# [64 rows x 3 columns]

# %%
# Hence correaltion nbetween latitute adn longitude is so high in trianing set.
# Lets drop latitute for now.
un_corr_predictors = set(train_corr[train_corr['correlation'].abs() < 0.8][['var_1', 'var_2']].values.reshape(-1))
un_corr_predictors
# Out:
# {'households',
#  'housing_median_age',
#  'latitude',
#  'longitude',
#  'median_income',
#  'population',
#  'total_bedrooms',
#  'total_rooms'}

# %% [markdown]
# ### Modelling

# %%
train_df.select(*un_corr_predictors).limit(5).toPandas()
# Out:
#    households  population  housing_median_age  longitude  median_income  \
# 0       472.0      1015.0                15.0    -114.31         1.4936
# 1       463.0      1129.0                19.0    -114.47         1.8200
# 2       117.0       333.0                17.0    -114.56         1.6509
# 3       226.0       515.0                14.0    -114.57         3.1917
# 4       262.0       624.0                20.0    -114.57         1.9250
#
#    latitude  total_bedrooms  total_rooms
# 0     34.19          1283.0       5612.0
# 1     34.40          1901.0       7650.0
# 2     33.69           174.0        720.0
# 3     33.64           337.0       1501.0
# 4     33.57           326.0       1454.0

# %%
from pyspark.ml.feature import StandardScaler
from pyspark.ml.regression import LinearRegression
from pyspark.ml import Pipeline
from pyspark.ml.tuning import TrainValidationSplit, ParamGridBuilder
from pyspark.ml.evaluation import RegressionEvaluator

# %%
evaluator = RegressionEvaluator().setLabelCol('median_house_value').setMetricName('mae')

# %%
lr = LinearRegression(featuresCol = 'StandardFeatures', labelCol = response, regParam = 0.01)
pipeline = Pipeline(stages=[
    VectorAssembler(inputCols = list(un_corr_predictors), outputCol="Features"),
    StandardScaler(withMean=True, withStd=True, inputCol="Features", outputCol="StandardFeatures"),
    lr
    ])

# %%
paramGrid = ParamGridBuilder().addGrid(lr.regParam, [0.1, 0.01]) \
                              .addGrid(lr.fitIntercept, [False, True])\
                              .addGrid(lr.elasticNetParam, [0.0, 0.5, 1.0])\
                              .build()

# %%
model = TrainValidationSplit(estimator = pipeline,
                             estimatorParamMaps = paramGrid,
                             evaluator = evaluator,
                             trainRatio = 0.8).fit(train_df)

# %% [markdown]
# ### Performance Evalaution

# %%
train_df_preds = model.transform(train_df).select(response, "prediction")
test_df_preds = model.transform(test_df).select(response, "prediction")

# %%
evaluator = RegressionEvaluator().setPredictionCol('prediction').setLabelCol('median_house_value').setMetricName('mae')

# %%
evaluator.evaluate(train_df_preds), evaluator.evaluate(test_df_preds)
# Out:
# (50800.25930223442, 50355.592475132595)
